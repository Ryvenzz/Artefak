# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('training_history50n.csv')

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['loss'], label=f'Training Loss Model 50 population', color='purple')
plt.plot(df['val_loss'], label=f'Validation Loss Model 50 population', linestyle='--', color='purple')

plt.title('Learning Curves for Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load history dari CSV
df_history = pd.read_csv('training_history50n.csv')

# Plot R²
plt.figure(figsize=(10, 6))
plt.plot(df_history['r2_score'], label='Training R² Model 50 Population', color='orange')
plt.plot(df_history['val_r2_score'], label='Validation R² Model 50 Population', linestyle='--', color='orange')

plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Learning Curves for R²')
# plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.show()

# %%
df.tail()
# Out:
#         loss  r2_score  val_loss  val_r2_score
# 26  0.499018  0.805086  0.796975      0.652975
# 27  0.543842  0.787578  0.839478      0.634468
# 28  0.544543  0.787304  0.775439      0.662352
# 29  0.650842  0.745786  0.828535      0.639233
# 30  0.518191  0.797598  0.779168      0.660729
