# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('training_history40n.csv')

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['loss'], label=f'Training Loss Model 40 population', color='orange')
plt.plot(df['val_loss'], label=f'Validation Loss Model 40 population', linestyle='--', color='orange')

plt.title('Learning Curves for Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load history dari CSV
df_history = pd.read_csv('training_history40n.csv')

# Plot R²
plt.figure(figsize=(10, 6))
plt.plot(df_history['r2_score'], label='Training R² Model 40 Population', color='orange')
plt.plot(df_history['val_r2_score'], label='Validation R² Model 40 Population', linestyle='--', color='orange')

plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Learning Curves for R²')
# plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.show()

# %%
df.tail()
# Out:
#         loss  r2_score  val_loss  val_r2_score
# 37  0.973750  0.619659  0.980855      0.572909
# 38  0.810342  0.683485  0.973745      0.576004
# 39  0.710378  0.722530  0.963134      0.580625
# 40  0.735375  0.712766  0.952070      0.585442
# 41  0.710039  0.722662  0.976697      0.574719
