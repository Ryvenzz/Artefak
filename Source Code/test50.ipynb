# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('training_history50.csv')

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['loss'], label=f'Training Loss Model 3', color='green')
plt.plot(df['val_loss'], label=f'Validation Loss Model 3', linestyle='--', color='green')

# plt.title('Learning Curves for All Models')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim(0, 1)
# plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['loss'], label=f'Training Loss Model 3', color='green')
plt.plot(df['val_loss'], label=f'Validation Loss Model 3', linestyle='--', color='green')

# plt.title('Learning Curves for All Models')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim(0, 1)
# plt.legend()
plt.grid(True)
plt.show()
