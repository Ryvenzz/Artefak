# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('training_history10n.csv')

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['loss'], label=f'Training Loss Model 10 population', color='red')
plt.plot(df['val_loss'], label=f'Validation Loss Model 10 population', linestyle='--', color='red')

plt.title('Learning Curves for Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load history dari CSV
df_history = pd.read_csv('training_history10n.csv')

# Plot R²
plt.figure(figsize=(10, 6))
plt.plot(df_history['r2_score'], label='Training R² Model 10 population', color='orange')
plt.plot(df_history['val_r2_score'], label='Validation R² Model 10 population', linestyle='--', color='orange')

plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Learning Curves for R²')
# plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.show()

# %%
df.tail()
# Out:
#         loss  r2_score  val_loss  val_r2_score
# 39  0.551363  0.784641  0.781539      0.659696
# 40  0.532757  0.791909  0.776779      0.661769
# 41  0.525054  0.794917  0.806216      0.648951
# 42  0.526725  0.794264  0.807897      0.648219
# 43  0.501831  0.803988  0.805674      0.649187
